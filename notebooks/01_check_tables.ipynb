# %%
# %sql
select * from nff_catalog_cd21_dev.bronze_raw.transactions

# %%
# %sql
select * from nff_catalog_cd21_dev.silver_refined.transactions;

# %%
# %sql
select * from nff_catalog_cd21_dev.gold_analytics.regional_kpis

# %%
# %sql
select * from nff_catalog_cd21_dev.quarantine.transactions
