# %%
import mlflow.spark
from mlflow.models.signature import infer_signature
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.sql.types import StringType, DoubleType, IntegerType, FloatType, DecimalType
import mlflow

# %%
def train_churn_model(table_name,experiment_name, run_name):
    # 1. Setup MLflow & Autologging
    # 2. Load Data and Cache them
    # 3. Feature Engineering for Categorical and Numerical features including VectorAssembler and StandardScaler
    # 4. Model Definition
    # 5. Pipeline Construction with MLFlow 
        # Train
        # Predict & Evaluate
        # Log Manual Params & Metrics
    # 6. Feature Importance Logging
    # 7. Signature and Model Logging
        # Clean up cache
